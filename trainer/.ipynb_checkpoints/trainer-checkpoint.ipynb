# %%
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            #  sep='^([^,]+),' gave error
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
# Clean folder ipynb_checkpoints
import os
 
os.system('rm -rf `find -type d -name .ipynb_checkpoints`')
# Out:
# 0

# %%
opt = get_config("config_files/en_filtered_config.yaml")
train(opt, amp=False) #%timeit

#if error withipynb_checkpoints
# use in terminal: rm -rf `find -type d -name .ipynb_checkpoints`
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: all_data
# opt.select_data: ['gum_train']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data	 dataset: gum_train
# all_data/gum_train
#     filename                                              words
# 0    209.jpg                 Esrombe Aramwei mɵskain gɵbig kɵn.
# 1     47.jpg                  Eleazarbe Matánwei mɵskain gɵben;
# 2    130.jpg               Ezequíasbe Manaséswei mɵskain gɵben;
# 3    267.jpg  "Kan srusrɵ mu mɵɵbagucha kimíig kwanrriig kɵr...
# 4     43.jpg                     Azorbe Sadocwei mɵskain gɵben;
# ..       ...                                                ...
# 229  234.jpg                           "Ɵyeeg chab srua amben,"
# 230   82.jpg      Incha Josébe unane Jesús munchi basrɵbig kɵn.
# 231  288.jpg                                     "Judea birau,"
# 232  170.jpg                           "Kerrigu ɵyeeg pureppe,"
# 233   63.jpg         "Nɵbe treeg martrab chab isubguen inchen,"
#
# [234 rows x 2 columns]
# sub-directory:	/gum_train	 num samples: 167
# <torch.utils.data.dataset.ConcatDataset object at 0x7fc3538bafe0>
# num total samples of gum_train: 167 x 1.0 (total_data_usage_ratio) = 167
# num samples of gum_train per batch: 32 x 1.0 (batch_ratio) = 32
# --------------------------------------------------------------------------------
# Total_batch_size: 32 = 32
# --------------------------------------------------------------------------------
# dataset_root:    all_data/gum_val	 dataset: /
# all_data/gum_val/
#    filename                                              words
# 0   235.jpg              Jeconíasbe Salatielwei mɵskain gɵben;
# 1   145.jpg           Inchen Eliudbe Eleazarwei mɵskain gɵben;
# 2    46.jpg           Inchen Eliudbe Eleazarwei mɵskain gɵben;
# 3   108.jpg                    Faresbe Esromwei mɵskain gɵben;
# 4   156.jpg  Incha tru israelitasmeran Babiloniamay srua am...
# 5   160.jpg  "Maríane maya misagwei malau ɵyeeg kuin gɵn ch...
# 6   204.jpg                  nui nunelaimba mɵskain gɵbig kɵn.
# 7    53.jpg  "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵll...
# 8    27.jpg                Jorambe Uzíaswei mɵskain gɵbig kɵn.
# 9   154.jpg  "Inchen David kɵb uraskurri tru israelitasmera...
# 10  208.jpg                    Faresbe Esromwei mɵskain gɵben;
# 11   42.jpg              Eliaquimbe Azorwei mɵskain gɵbig kɵn.
# 12  159.jpg  "Inchen José tru nui keg kɵnrrabiibe sɵlgandɵ ...
# 13   21.jpg  Uríaswei srain gɵbiibabe Salomónwɵi mɵskalɵ gɵ...
# 14   38.jpg              Jeconíasbe Salatielwei mɵskain gɵben;
# 15  198.jpg  "Kaguende ñuinukkurrimbe misagwan ashib karunr...
# 16  179.jpg  "Incha Josébe Marían nui nusrkawan tɵgagɵmnega...
# 17  268.jpg                               kan unɵ tɵgagɵnrrun.
# 18  103.jpg                    Isaacbe Jacobwei mɵskain gɵben;
# 19  124.jpg             Inchen Asabe Josafatwei mɵskain gɵben;
# 20  271.jpg   (Tru Emanuel munchibe Tiusbe namba basran daig).
# 21  289.jpg                            "ñi Belén pueblounɵbe,"
# 22  221.jpg                 Abíasbe Asaiwei mɵskain gɵbig kɵn.
# 23  215.jpg                         nui usrimbe Rut gɵbig kɵn.
# 24  250.jpg  "Inchen David kɵb uraskurri tru israelitasmera...
# 25   99.jpg  "Kaguende ñuinukkurrimbe misagwan ashib karunr...
# 26  206.jpg                          "Zaraimba mɵskain gɵben,"
# 27   83.jpg  "Jesúsbe Judea birau Belén puebloyu kallabig k...
# 28  182.jpg  "Jesúsbe Judea birau Belén puebloyu kallabig k...
# 29   93.jpg   payibig kɵn: ¿Cristobe chu gallanrrabig kɵ? cha.
# 30   65.jpg                 "ñi Davidwei misagugurri arrubig,"
# 31  143.jpg                Sadocbe Aquimwei mɵskain gɵbig kɵn.
# 32  136.jpg                           "Ɵyeeg chab srua amben,"
# 33   60.jpg  "Inchen José tru nui keg kɵnrrabiibe sɵlgandɵ ...
# 34    1.jpg                         "tru Davidweinukkurrimba,"
# 35  157.jpg  "Jesucristo kallaibe ɵyeeg kuig kɵn: María nui...
# 36  272.jpg           "Incha José tru piabyugurri kiagasrabe,"
# 37   57.jpg  Incha tru israelitasmeran Babiloniamay srua am...
# 38   87.jpg        kɵriibala nune tabig waminchab amrruer cha.
# 39   23.jpg                   Roboambe Abíaswei mɵskain gɵben;
# 40   48.jpg                    Matánbe Jacobwei mɵskain gɵben;
# 41  180.jpg      sraimba lataig nɵmui asrtɵga chi marmuig kɵn.
# 42   84.jpg                    Herodes tru birau rey gɵb uras.
# 43  285.jpg       "tru Moisés pɵrigwan kusrenanɵbelanba wama,"
# 44  188.jpg                  ni mumaygucha gɵmui inchibig kɵn.
# 45  129.jpg              Acazbe Ezequíaswei mɵskain gɵbig kɵn.
# 46  117.jpg                    "Obedbe Isaíwei mɵskain gɵben,"
# 47  287.jpg  Inchen nɵmbe trenchibelɵ gɵn: Judea birau Belé...
# 48  173.jpg            "Truibe Emanuel cha wamig kɵnrrun cha,"
# 49   94.jpg  Inchen nɵmbe trenchibelɵ gɵn: Judea birau Belé...
# 50  191.jpg       "tru Moisés pɵrigwan kusrenanɵbelanba wama,"
# 51   55.jpg  "Inchen David kɵb uraskurri tru israelitasmera...
# 52  132.jpg                Amonbe Josíaswei mɵskain gɵbig kɵn.
# 53  263.jpg                       "Nɵbe kan mɵgunɵ tɵgagɵben,"
# 54   50.jpg              "Inchen tru Josébe Maríai keg kɵben,"
# 55   10.jpg                 Esrombe Aramwei mɵskain gɵbig kɵn.
# 56  244.jpg                 Jacobpe Joséwei mɵskain gɵbig kɵn.
# 57  152.jpg  "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵll...
# 58  120.jpg  Uríaswei srain gɵbiibabe Salomónwɵi mɵskalɵ gɵ...
# sub-directory:	/.	 num samples: 41
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 64 600 20 1 256 256 61 400 None VGG BiLSTM CTC
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=61, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.0.weight 288
# module.FeatureExtraction.ConvNet.0.bias 32
# module.FeatureExtraction.ConvNet.3.weight 18432
# module.FeatureExtraction.ConvNet.3.bias 64
# module.FeatureExtraction.ConvNet.6.weight 73728
# module.FeatureExtraction.ConvNet.6.bias 128
# module.FeatureExtraction.ConvNet.8.weight 147456
# module.FeatureExtraction.ConvNet.8.bias 128
# module.FeatureExtraction.ConvNet.11.weight 294912
# module.FeatureExtraction.ConvNet.12.weight 256
# module.FeatureExtraction.ConvNet.12.bias 256
# module.FeatureExtraction.ConvNet.14.weight 589824
# module.FeatureExtraction.ConvNet.15.weight 256
# module.FeatureExtraction.ConvNet.15.bias 256
# module.FeatureExtraction.ConvNet.18.weight 262144
# module.FeatureExtraction.ConvNet.18.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 15616
# module.Prediction.bias 61
# Total Trainable Params: 3772093
# Trainable params num :  3772093
# Optimizer:
# Adadelta (
# Parameter Group 0
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     lr: 1.0
#     maximize: False
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: 0123456789
# symbol: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €
# lang_char: None
# experiment_name: en_sample
# train_data: all_data
# valid_data: all_data/gum_val
# manualSeed: 1111
# workers: 6
# batch_size: 32
# num_iter: 300
# valInterval: 10
# saved_model:
# FT: False
# optim: False
# lr: 1.0
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['gum_train']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 400
# imgH: 64
# imgW: 600
# rgb: False
# contrast_adjust: 0.0
# sensitive: True
# PAD: True
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character:  "(),.:;?ABCDEFHIJKMNORSTUZabcdefghiklmnopqrstuvwyz¿áéíñóúƟɵ
# num_class: 61
# ---------------------------------------
#
# training time:  14.563028812408447
# [10/300] Train loss: 6.48116, Valid loss: 3.92077, Elapsed_time: 14.56330
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Uríaswei srain gɵbiibabe Salomónwɵi mɵskalɵ gɵbig kɵn. |                           | 0.0000	False
# "Inchen David kɵb uraskurri tru israelitasmeran Babiloniamay merrarrawa srua ambub uraskatig katɵgan catorce treetɵwei katɵle srɵig," |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  1.0165209770202637
# training time:  1.8362364768981934
# [20/300] Train loss: 4.25380, Valid loss: 3.87917, Elapsed_time: 17.41627
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# (Tru Emanuel munchibe Tiusbe namba basran daig). |                           | 0.0000	False
# Sadocbe Aquimwei mɵskain gɵbig kɵn. |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5168325901031494
# training time:  1.8263447284698486
# [30/300] Train loss: 3.92169, Valid loss: 3.70749, Elapsed_time: 19.75966
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Abíasbe Asaiwei mɵskain gɵbig kɵn. |                           | 0.0000	False
# nui usrimbe Rut gɵbig kɵn. |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5156986713409424
# training time:  1.4306416511535645
# [40/300] Train loss: 3.68602, Valid loss: 3.60637, Elapsed_time: 21.70622
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "tru Davidweinukkurrimba," |                           | 0.0000	False
# "Inchen David kɵb uraskurri tru israelitasmeran Babiloniamay merrarrawa srua ambub uraskatig katɵgan catorce treetɵwei katɵle srɵig," |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5119729042053223
# training time:  1.8218858242034912
# [50/300] Train loss: 3.55420, Valid loss: 3.52821, Elapsed_time: 24.04030
# Current_accuracy : 0.000, Current_norm_ED  : 0.0020
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0020
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Kaguende ñuinukkurrimbe misagwan ashib karunrrabig kan webattrun cha," |                           | 0.0000	False
# Uríaswei srain gɵbiibabe Salomónwɵi mɵskalɵ gɵbig kɵn. |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5819096565246582
# training time:  1.8282206058502197
# [60/300] Train loss: 3.46724, Valid loss: 3.45618, Elapsed_time: 26.45065
# Current_accuracy : 0.000, Current_norm_ED  : 0.0063
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0063
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# sraimba lataig nɵmui asrtɵga chi marmuig kɵn. |                           | 0.0000	False
# "Zaraimba mɵskain gɵben," |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5916805267333984
# training time:  1.4397070407867432
# [70/300] Train loss: 3.38822, Valid loss: 3.35185, Elapsed_time: 28.48223
# Current_accuracy : 0.000, Current_norm_ED  : 0.0169
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0169
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | ".                        | 0.0000	False
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | .                         | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5917043685913086
# training time:  1.8439366817474365
# [80/300] Train loss: 3.31998, Valid loss: 3.38282, Elapsed_time: 30.91808
# Current_accuracy : 0.000, Current_norm_ED  : 0.0212
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0212
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# kan unɵ tɵgagɵnrrun.      | "                         | 0.0000	False
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | ".                        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5882031917572021
# training time:  1.842437982559204
# [90/300] Train loss: 3.29266, Valid loss: 3.28259, Elapsed_time: 33.34893
# Current_accuracy : 0.000, Current_norm_ED  : 0.0289
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0289
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Faresbe Esromwei mɵskain gɵben; | ".                        | 0.0000	False
# Uríaswei srain gɵbiibabe Salomónwɵi mɵskalɵ gɵbig kɵn. | "n,.                      | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5924746990203857
# training time:  1.433802604675293
# [100/300] Train loss: 3.22556, Valid loss: 3.30895, Elapsed_time: 35.37544
# Current_accuracy : 0.000, Current_norm_ED  : 0.0465
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0465
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Truibe Emanuel cha wamig kɵnrrun cha," | "n.                       | 0.0000	False
# "Zaraimba mɵskain gɵben," | ","                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5882937908172607
# training time:  1.8443641662597656
# [110/300] Train loss: 3.14267, Valid loss: 3.20746, Elapsed_time: 37.80831
# Current_accuracy : 0.000, Current_norm_ED  : 0.0429
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0465
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Esrombe Aramwei mɵskain gɵbig kɵn. | "n.                       | 0.0000	False
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | ",.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5260903835296631
# training time:  1.8359096050262451
# [120/300] Train loss: 3.07477, Valid loss: 3.29080, Elapsed_time: 40.17053
# Current_accuracy : 0.000, Current_norm_ED  : 0.0429
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0465
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# kan unɵ tɵgagɵnrrun.      | ","                       | 0.0000	False
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | ",.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5260882377624512
# training time:  1.4380340576171875
# [130/300] Train loss: 3.04334, Valid loss: 3.24116, Elapsed_time: 42.13488
# Current_accuracy : 0.000, Current_norm_ED  : 0.0475
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0475
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "ñi Belén pueblounɵbe,"   | "n.                       | 0.0000	False
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | "n.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5820286273956299
# training time:  1.791599988937378
# [140/300] Train loss: 3.03083, Valid loss: 3.19045, Elapsed_time: 44.50872
# Current_accuracy : 0.000, Current_norm_ED  : 0.0435
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0475
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Ɵyeeg chab srua amben,"  | ",.                       | 0.0000	False
# nui nunelaimba mɵskain gɵbig kɵn. | "n.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5283434391021729
# training time:  1.822709321975708
# [150/300] Train loss: 2.95684, Valid loss: 3.19261, Elapsed_time: 46.86000
# Current_accuracy : 0.000, Current_norm_ED  : 0.0459
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0475
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Kaguende ñuinukkurrimbe misagwan ashib karunrrabig kan webattrun cha," | "n"                       | 0.0000	False
# "Inchen David kɵb uraskurri tru israelitasmeran Babiloniamay merrarrawa srua ambub uraskatig katɵgan catorce treetɵwei katɵle srɵig," | ","                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5331087112426758
# training time:  1.4286582469940186
# [160/300] Train loss: 3.02388, Valid loss: 3.17728, Elapsed_time: 48.82196
# Current_accuracy : 0.000, Current_norm_ED  : 0.0470
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0475
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Obedbe Isaíwei mɵskain gɵben," | tn.                       | 0.0000	False
# "Truibe Emanuel cha wamig kɵnrrun cha," | "n.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5340368747711182
# training time:  1.8126544952392578
# [170/300] Train loss: 2.98861, Valid loss: 3.40345, Elapsed_time: 51.16887
# Current_accuracy : 0.000, Current_norm_ED  : 0.0427
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0475
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# payibig kɵn: ¿Cristobe chu gallanrrabig kɵ? cha. | "n"                       | 0.0000	False
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | "n.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5308549404144287
# training time:  1.8306868076324463
# [180/300] Train loss: 3.00018, Valid loss: 3.27337, Elapsed_time: 53.53063
# Current_accuracy : 0.000, Current_norm_ED  : 0.0665
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0665
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Esrombe Aramwei mɵskain gɵbig kɵn. | "Ie,"                     | 0.0000	False
# "Inchen David kɵb uraskurri tru israelitasmeran Babiloniamay merrarrawa srua ambub uraskatig katɵgan catorce treetɵwei katɵle srɵig," | n.                        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5923202037811279
# training time:  1.4044790267944336
# [190/300] Train loss: 3.00338, Valid loss: 3.08669, Elapsed_time: 55.52765
# Current_accuracy : 0.000, Current_norm_ED  : 0.0600
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0665
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Acazbe Ezequíaswei mɵskain gɵbig kɵn. | "en;                      | 0.0000	False
# kan unɵ tɵgagɵnrrun.      | "n"                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5309286117553711
# training time:  1.7898039817810059
# [200/300] Train loss: 2.89964, Valid loss: 3.15637, Elapsed_time: 57.84860
# Current_accuracy : 0.000, Current_norm_ED  : 0.0643
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0665
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Kaguende ñuinukkurrimbe misagwan ashib karunrrabig kan webattrun cha," | "an,"                     | 0.0000	False
# Uríaswei srain gɵbiibabe Salomónwɵi mɵskalɵ gɵbig kɵn. | "n.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.536322832107544
# training time:  1.8482637405395508
# [210/300] Train loss: 2.94312, Valid loss: 3.18036, Elapsed_time: 60.23340
# Current_accuracy : 0.000, Current_norm_ED  : 0.0634
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0665
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Obedbe Isaíwei mɵskain gɵben," | "en"                      | 0.0000	False
# "Kaguende ñuinukkurrimbe misagwan ashib karunrrabig kan webattrun cha," | "rn,"                     | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5286910533905029
# training time:  1.435765027999878
# [220/300] Train loss: 2.92289, Valid loss: 3.25362, Elapsed_time: 62.19807
# Current_accuracy : 0.000, Current_norm_ED  : 0.0495
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0665
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Inchen David kɵb uraskurri tru israelitasmeran Babiloniamay merrarrawa srua ambub uraskatig katɵgan catorce treetɵwei katɵle srɵig," | n"                        | 0.0000	False
# Esrombe Aramwei mɵskain gɵbig kɵn. | "n.                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5298097133636475
# training time:  1.8061034679412842
# [230/300] Train loss: 2.92115, Valid loss: 3.20323, Elapsed_time: 64.53420
# Current_accuracy : 0.000, Current_norm_ED  : 0.0607
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0665
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Nɵbe kan mɵgunɵ tɵgagɵben," | "e,"                      | 0.0000	False
# payibig kɵn: ¿Cristobe chu gallanrrabig kɵ? cha. | "an"                      | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5323946475982666
# training time:  1.8609495162963867
# [240/300] Train loss: 2.90030, Valid loss: 3.41333, Elapsed_time: 66.92775
# Current_accuracy : 0.000, Current_norm_ED  : 0.0677
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0677
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# payibig kɵn: ¿Cristobe chu gallanrrabig kɵ? cha. | "an,.                     | 0.0000	False
# Eliaquimbe Azorwei mɵskain gɵbig kɵn. | "rn,.                     | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5966978073120117
# training time:  1.4051744937896729
# [250/300] Train loss: 2.85468, Valid loss: 3.28131, Elapsed_time: 68.92982
# Current_accuracy : 0.000, Current_norm_ED  : 0.0639
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0677
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Faresbe Esromwei mɵskain gɵben; | "n.                       | 0.0000	False
# ni mumaygucha gɵmui inchibig kɵn. | "rn.                      | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.526538610458374
# training time:  1.850597620010376
# [260/300] Train loss: 2.81652, Valid loss: 3.19219, Elapsed_time: 71.30717
# Current_accuracy : 0.000, Current_norm_ED  : 0.0715
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0715
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | "uen.                     | 0.0000	False
# Acazbe Ezequíaswei mɵskain gɵbig kɵn. | "rn.                      | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5858900547027588
# training time:  1.8137688636779785
# [270/300] Train loss: 2.86817, Valid loss: 3.21586, Elapsed_time: 73.70704
# Current_accuracy : 0.000, Current_norm_ED  : 0.0743
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "ñi Belén pueblounɵbe,"   | nn,"                      | 0.0000	False
# Inchen Eliudbe Eleazarwei mɵskain gɵben; | "Kan.                     | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.6030228137969971
# training time:  1.4369947910308838
# [280/300] Train loss: 2.80041, Valid loss: 3.07774, Elapsed_time: 75.74727
# Current_accuracy : 0.000, Current_norm_ED  : 0.0796
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0796
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | "ae,"                     | 0.0000	False
# nui usrimbe Rut gɵbig kɵn. | "Ken.                     | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.601222038269043
# training time:  1.848787784576416
# [290/300] Train loss: 2.91197, Valid loss: 3.11064, Elapsed_time: 78.19751
# Current_accuracy : 0.000, Current_norm_ED  : 0.0840
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0840
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "tru Moisés pɵrigwan kusrenanɵbelanba wama," | "aɵn.                     | 0.0000	False
# Eliaquimbe Azorwei mɵskain gɵbig kɵn. | "aɵn,"                    | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5916059017181396
# training time:  1.861900806427002
# [300/300] Train loss: 2.73740, Valid loss: 3.34633, Elapsed_time: 80.65122
# Current_accuracy : 0.000, Current_norm_ED  : 0.0825
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0840
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Uríaswei srain gɵbiibabe Salomónwɵi mɵskalɵ gɵbig kɵn. | "ae,"                     | 0.0000	False
# "Inchawei Abraham kɵb uraskurri merrabsrɵ kɵlli misaamerai ureemera katɵle srɵig," | "ae,"                     | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  0.5355486869812012
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
